# %% [markdown]
# # Preprocess Data
#
# Preprocess all data into a joined dataframe

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timezone
from dateutil.parser import parse
import matplotlib.pyplot as plt
import math
import os
import pickle
import requests

# %%
# Check that the reference directory exists
for dirname, _, filenames in os.walk('../COVID-19/csse_covid_19_data/csse_covid_19_time_series/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/README.md
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/.gitignore
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv
# ../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv

# %%
us_confirmed_df = pd.read_csv('../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv')
world_confirmed_df = pd.read_csv('../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
us_deaths_df = pd.read_csv('../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv')
world_deaths_df = pd.read_csv('../COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
us_confirmed_df[us_confirmed_df.FIPS <= 36.1][['UID',
 'iso2',
 'iso3',
 'code3',
 'FIPS',
 'Admin2',
 'Province_State',
 'Country_Region',
 'Lat',
 'Long_',
 'Combined_Key',]]
# Out:
# Empty DataFrame
# Columns: [UID, iso2, iso3, code3, FIPS, Admin2, Province_State, Country_Region, Lat, Long_, Combined_Key]
# Index: []

# %%
# https://www2.census.gov/programs-surveys/popest/datasets/2010-2019/counties/totals/co-est2019-alldata.csv
county_census_df = pd.read_csv('./data/co-est2019-alldata.csv', encoding='latin-1')
county_census_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0        4779736            4780125          4785437  ...          1.917501
# 1          54571              54597            54773  ...          4.847310
# 2         182265             182265           183112  ...         24.017829
# 3          27457              27455            27327  ...         -5.690302
# 4          22915              22915            22870  ...          1.385134
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# 0     0.578434     1.186314     1.522549     0.563489     0.626357
# 1     6.018182    -6.226119    -3.902226     1.970443    -1.712875
# 2    16.641870    17.488579    22.751474    20.184334    17.725964
# 3     0.292676    -6.897817    -8.132185    -5.140431   -15.724575
# 4    -4.998356    -3.787545    -5.797999     1.331144     1.329817
#
#    RNETMIG2016  RNETMIG2017  RNETMIG2018  RNETMIG2019
# 0     0.745172     1.090366     1.773786     2.483744
# 1     4.777171     0.849656     0.540916     4.560062
# 2    21.279291    22.398256    24.727215    24.380567
# 3   -18.238016   -24.998528    -8.754922    -5.165664
# 4    -0.708717    -3.234669    -6.857092     1.831952
#
# [5 rows x 164 columns]

# %% [markdown]
# # Reformat data so dates are values instead of columns

# %%
def is_date(string, fuzzy=False):
    """
    Return whether the string can be interpreted as a date.

    :param string: str, string to check for date
    :param fuzzy: bool, ignore unknown tokens in string if True
    """
    try: 
        parse(string, fuzzy=fuzzy)
        return True

    except ValueError:
        return False
    
def get_county(string):
    str_array = string.split(',')
    if len(str_array) < 3:
        return ''
    else:
        return str_array[0]

# %%
date_cols = [x for x in list(us_confirmed_df) if is_date(x)]
dates = [datetime.strptime(x , '%m/%d/%y') for x in date_cols]

column_names = ['FIPS', 'County', 'Province_State', 'Country_Region', 'Date', 'Cases', 'Deaths', 'Population']

combined_df = pd.DataFrame(columns=column_names)

for index, row in us_confirmed_df.iterrows():
    fips = row['FIPS']
    if math.isnan(fips):
        print('skipping county', county, fips, population)
        continue
    population = county_census_df[
        (county_census_df.STATE == int(fips / 1000))
        & (county_census_df.COUNTY == int(fips % 1000))]['POPESTIMATE2019']
    if len(population) != 1:
        print('skipping county', county, fips, population)
        continue
    county = get_county(row['Combined_Key'])
    population = population.to_numpy()[0]
    for (date_col, date) in zip(date_cols, dates):
        confirmed = row[date_col]
        if confirmed == 0:
            continue
        if date_col in us_deaths_df:
            deaths = us_deaths_df[us_deaths_df.FIPS == row['FIPS']][date_col].to_numpy()[0]
        else:
            deaths = 0
            
        values = [fips, county, row['Province_State'], row['Country_Region'], date, confirmed, deaths, population]
        df_length = len(combined_df)
        combined_df.loc[df_length] = values
    if index % 100 == 0:
        print('processed {} out of {}'.format(index, len(us_confirmed_df)))
combined_df.head()
# Out:
# skipping county Weston 60.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 66.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 69.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 72.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 78.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# processed 100 out of 3253
# processed 200 out of 3253
# processed 300 out of 3253
# processed 400 out of 3253
# processed 500 out of 3253
# processed 600 out of 3253
# processed 700 out of 3253
# processed 800 out of 3253
# processed 900 out of 3253
# processed 1000 out of 3253
# processed 1100 out of 3253
# processed 1200 out of 3253
# processed 1300 out of 3253
# processed 1400 out of 3253
# processed 1500 out of 3253
# processed 1600 out of 3253
# processed 1700 out of 3253
# processed 1800 out of 3253
# processed 1900 out of 3253
# processed 2000 out of 3253
# processed 2100 out of 3253
# processed 2200 out of 3253
# processed 2300 out of 3253
# processed 2400 out of 3253
# processed 2500 out of 3253
# processed 2600 out of 3253
# processed 2700 out of 3253
# processed 2800 out of 3253
# processed 2900 out of 3253
# processed 3000 out of 3253
# processed 3100 out of 3253
# skipping county Weston nan 6927
# skipping county Weston nan 6927
# skipping county Weston 80001.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80002.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80004.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80005.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80006.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80008.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80009.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80010.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80011.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80012.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80013.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80015.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80016.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80017.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80018.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80019.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80020.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80021.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80022.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80023.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80024.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80025.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80026.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80027.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80028.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80029.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80030.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80031.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80032.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80033.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80034.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80035.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80036.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80037.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80038.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80039.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80040.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80041.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80042.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80044.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80045.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80046.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80047.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80048.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80049.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80050.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80051.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80053.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80054.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80055.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 80056.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 88888.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90001.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90002.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90004.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90005.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90006.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90008.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90009.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90010.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90011.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90012.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90013.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90015.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90016.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90017.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90018.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90019.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90020.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90021.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90022.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90023.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90024.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90025.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90026.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90027.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90028.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90029.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90030.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90031.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90032.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90033.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90034.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90035.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90036.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90037.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90038.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90039.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90040.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90041.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90042.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90044.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90045.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90046.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90047.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90048.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90049.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90050.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90051.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90053.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90054.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90055.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 90056.0 Series([], Name: POPESTIMATE2019, dtype: int64)
# skipping county Weston 99999.0 Series([], Name: POPESTIMATE2019, dtype: int64)
#      FIPS   County Province_State Country_Region       Date Cases Deaths  \
# 0  1001.0  Autauga        Alabama             US 2020-03-24     1      0
# 1  1001.0  Autauga        Alabama             US 2020-03-25     4      0
# 2  1001.0  Autauga        Alabama             US 2020-03-26     6      0
# 3  1001.0  Autauga        Alabama             US 2020-03-27     6      0
# 4  1001.0  Autauga        Alabama             US 2020-03-28     6      0
#
#   Population
# 0      55869
# 1      55869
# 2      55869
# 3      55869
# 4      55869

# %%
with open('./data/us_combined_df.pkl', 'wb') as f:
    pickle.dump(combined_df, f)
